# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("russian") 
stemmer.stem("границу")
# Out:
# 'границ'

# %%
границу

# %%
text = str()
with open("../dumps-text/ru_total2.txt", "r") as f:
    text = f.read()
#text

# %%
import string
import re

text = text.lower()
#text
spec_chars = string.punctuation + '\n\xa0«»\t—…'
text = re.sub('\n', '', text)
#text
text = "".join([ch for ch in text if ch not in spec_chars])
#text

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
import nltk

text_tokens = word_tokenize(text)
text = nltk.Text(text_tokens)

russian_stopwords = stopwords.words("russian")
russian_stopwords.extend(['это', 'нею', 'button', 'twitter', 'telegram', 'livejournal', 'года', 'который', 'изза'])

text_tokens = [token.strip() for token in text_tokens if token not in russian_stopwords]
text = nltk.Text(text_tokens)
print(text)
# Out:
# <Text: rss feed for thevillageru iframe httpswwwgoogletagmanagercomnshtmlidgtmkr29wms удивляйтесь унижают...>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

text_raw = " ".join(text)

wordcloud = WordCloud().generate(text_raw)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
